# %%
#Required libraries
pip install pandas
pip install matplotlib
pip install openpyxl
pip install seaborn
pip install mlxtend
# Out:
#   Cell In[1], line 2
#     pip install pandas
#         ^
# SyntaxError: invalid syntax

# %% [markdown]
# TODO : curate null (empty) customer IDs
# keep the results with those IDs and compare without IDs

# %%
import pandas as pd
import matplotlib.pyplot as plt
pd.plotting.register_matplotlib_converters()

# %matplotlib inline
import seaborn as sns
print("Setup Complete")
# Out:
# Setup Complete

# %%
df = pd.read_excel('data.xlsx') # reads the excel file
df_original = pd.read_excel('data.xlsx') #copy it for further comparisons
sns.scatterplot(x="Quantity",y="UnitPrice",data=df) # creates a scatter plot with columns xvar and yvar
# Out:
# <Axes: xlabel='Quantity', ylabel='UnitPrice'>

# %%
df.info()
#Here we can see 8 different columns are contained in this file
#Not all of them are useful for our application
#InvoiceNo, StockCode, Description, Quantity, InvoiceDate, UnitPrice, CustomerID, Country
df.nunique()

#We can see there are 25 900 different invoices
#4 070 different stock codes (products)
#
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    541909 non-null  object
#  1   StockCode    541909 non-null  object
#  2   Description  540455 non-null  object
#  3   Quantity     541909 non-null  int64
#  4   InvoiceDate  541909 non-null  datetime64[ns]
#  5   UnitPrice    541909 non-null  float64
#  6   CustomerID   406829 non-null  float64
#  7   Country      541909 non-null  object
# dtypes: datetime64[ns](1), float64(2), int64(1), object(4)
# memory usage: 33.1+ MB
# InvoiceNo      25900
# StockCode       4070
# Description     4223
# Quantity         722
# InvoiceDate    23260
# UnitPrice       1630
# CustomerID      4372
# Country           38
# dtype: int64

# %%
#remove duplicates

print("Original number of rows : ", len(df_original.index))
df.drop_duplicates()
print("Number of rows after removing duplicates :", len(df.index))
#no duplicate rows apparent

#remove rows where unit price < 0

df = df[df['UnitPrice'] >= 0]
print("Number of rows after removing negative prices :", len(df.index))

#remove rows where quantity < 0

df = df[df['Quantity'] >= 0]
print("Number of rows after removing negative quantities :", len(df.index))

df_no_null_customer = df[df['CustomerID'].notnull()]
print("Number of rows after removing empty customers ID :", len(df_no_null_customer.index))

print("Number of rows after removing negative quantities :", len(df.index))

sns.scatterplot(x="Quantity",y="UnitPrice",data=df) # creates a scatter plot with columns xvar and yvar
# Out:
# Original number of rows :  541909
# Number of rows after removing duplicates : 541909
# Number of rows after removing negative prices : 541907
# Number of rows after removing negative quantities : 531283
# Number of rows after removing empty customers ID : 397924
# Number of rows after removing negative quantities : 531283
# <Axes: xlabel='Quantity', ylabel='UnitPrice'>

# %%
#how about we remove the extremes ?

# %%
df.head()
#about the data :
#stockcode and description are redundant
#invoiceDate is not exploitable
#customerID is not exploitable
#country is not exploitable
#Reminder : we are looking for some association rules between products
#unitPrice is not exploitable (unsure) (maybe interesting to see price evolve with quantity)

to_drop = ['InvoiceDate',
           'Country',
           'CustomerID',
           'StockCode']

to_drop_original = ['InvoiceDate',
           'Country',
           'CustomerID',
           'stockCode']

# %%
#drop those tables

df_original.drop(to_drop, inplace=True, axis=1)

df_original.head()
# Out:
#   InvoiceNo                          Description  Quantity  UnitPrice
# 0    536365   WHITE HANGING HEART T-LIGHT HOLDER         6       2.55
# 1    536365                  WHITE METAL LANTERN         6       3.39
# 2    536365       CREAM CUPID HEARTS COAT HANGER         8       2.75
# 3    536365  KNITTED UNION FLAG HOT WATER BOTTLE         6       3.39
# 4    536365       RED WOOLLY HOTTIE WHITE HEART.         6       3.39

# %%
df_original.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice  CustomerID         Country
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 2 2010-12-01 08:26:00       2.75     17850.0  United Kingdom
# 3 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 4 2010-12-01 08:26:00       3.39     17850.0  United Kingdom

# %%
#for association rules I will need to convert each product into a boolean
#and group orders by Description
df_original = df_original.pivot_table(
              index='InvoiceNo', 
              columns='Description', 
              values='Quantity', 
              aggfunc='sum').fillna(0).astype(bool)

df_original.head()

# %%
# Support value for single items
support = df_original.mean().sort_values(ascending=False)
support.head(10)
# Out:
# Description
# WHITE HANGING HEART T-LIGHT HOLDER    0.094167
# REGENCY CAKESTAND 3 TIER              0.088726
# JUMBO BAG RED RETROSPOT               0.087335
# PARTY BUNTING                         0.069786
# LUNCH BAG RED RETROSPOT               0.065737
# ASSORTED COLOUR BIRD ORNAMENT         0.060010
# SET OF 3 CAKE TINS PANTRY DESIGN      0.059642
# PACK OF 72 RETROSPOT CAKE CASES       0.054569
# LUNCH BAG  BLACK SKULL.               0.052974
# NATURAL SLATE HEART CHALKBOARD        0.051788
# dtype: float64

# %%
from mlxtend.frequent_patterns import association_rules, apriori

# Apply Apriori algorithm
frequent_itemsets = apriori(df_original, min_support=0.01, use_colnames=True)

# %%
frequent_itemsets.sort_values(by='support', ascending=False).head(20)
# Out:
#       support                              itemsets
# 609  0.094167  (WHITE HANGING HEART T-LIGHT HOLDER)
# 434  0.088726            (REGENCY CAKESTAND 3 TIER)
# 258  0.087335             (JUMBO BAG RED RETROSPOT)
# 353  0.069786                       (PARTY BUNTING)
# 294  0.065737             (LUNCH BAG RED RETROSPOT)
# 38   0.060010       (ASSORTED COLOUR BIRD ORNAMENT)
# 490  0.059642   (SET OF 3 CAKE TINS PANTRY DESIGN )
# 336  0.054569     (PACK OF 72 RETROSPOT CAKE CASES)
# 286  0.052974             (LUNCH BAG  BLACK SKULL.)
# 316  0.051788     (NATURAL SLATE HEART CHALKBOARD )
# 391  0.051133                             (POSTAGE)
# 256  0.050356             (JUMBO BAG PINK POLKADOT)
# 243  0.049906            (JAM MAKING SET WITH JARS)
# 224  0.049579               (HEART OF WICKER SMALL)
# 269  0.049129              (JUMBO STORAGE BAG SUKI)
# 267  0.048556   (JUMBO SHOPPER VINTAGE RED PAISLEY)
# 242  0.048024              (JAM MAKING SET PRINTED)
# 289  0.047983                 (LUNCH BAG CARS BLUE)
# 295  0.047861          (LUNCH BAG SPACEBOY DESIGN )
# 346  0.047861     (PAPER CHAIN KIT 50'S CHRISTMAS )

# %%
# Compute association rules

rules = association_rules(frequent_itemsets, metric="confidence", 
  min_threshold=0.5)

# %%
#We obtain the table with
#support
#between 0 and 1 and represents the percentage of times where this transaction happens
#ex : 1,8% of transactions have 60 TEATIME FAIRY CAKE CASES and PACK OF 72 RETROSPOT CAKE CASES

#confidence
#between 0 and 1 and represents the percentage of times where a transaction with A will have B as well
#ex : 54,8% of transactions containing 60 TEATIME FAIRY CAKE CASES will also have PACK OF 72 RETROSPOT CAKE CASES

#lift
#lift is used to make the difference between a product that occurs frequently in general and a product that occurs frequently
#in a specific association
#We want to avoid considering meaningless associations (example of the paper bag being bought always with the apple)
#ex : 60 TEATIME FAIRY CAKE CASES and PACK OF 72 RETROSPOT CAKE CASES have a lift of 10, which is excellent,
#it means those two products are not only often bought together, but also not always bought all the time with anything else

#leverage


#conviction
#serves to measure how much a consequent depends on antecedant
#a high conviction means the consequent is highly dependant on the antecedant

#zhangs_metric
rules.head()
# Out:
#                         antecedents                        consequents  \
# 0     (60 TEATIME FAIRY CAKE CASES)  (PACK OF 72 RETROSPOT CAKE CASES)
# 1  (ALARM CLOCK BAKELIKE CHOCOLATE)       (ALARM CLOCK BAKELIKE GREEN)
# 2  (ALARM CLOCK BAKELIKE CHOCOLATE)        (ALARM CLOCK BAKELIKE RED )
# 3      (ALARM CLOCK BAKELIKE IVORY)       (ALARM CLOCK BAKELIKE GREEN)
# 4     (ALARM CLOCK BAKELIKE ORANGE)       (ALARM CLOCK BAKELIKE GREEN)
#
#    antecedent support  consequent support   support  confidence       lift  \
# 0            0.034198            0.054569  0.018735    0.547847  10.039479
# 1            0.018040            0.040947  0.011372    0.630385  15.395009
# 2            0.018040            0.044220  0.012108    0.671202  15.178723
# 3            0.023848            0.040947  0.013745    0.576329  14.074872
# 4            0.018899            0.040947  0.011331    0.599567  14.642375
#
#    leverage  conviction  zhangs_metric
# 0  0.016869    2.090953       0.932275
# 1  0.010633    2.594737       0.952222
# 2  0.011311    2.906890       0.951279
# 3  0.012768    2.263675       0.951647
# 4  0.010557    2.395039       0.949652

# %%
# That's it for now !
# Everything after is past attempts / dead ends
# Out:
#                                            antecedents
# 369  (REGENCY TEA PLATE ROSES , REGENCY TEA PLATE P...  \
# 370  (REGENCY TEA PLATE GREEN , REGENCY TEA PLATE P...
# 382  (CHARLOTTE BAG SUKI DESIGN, STRAWBERRY CHARLOT...
# 405  (ROSES REGENCY TEACUP AND SAUCER , PINK REGENC...
# 124                           (REGENCY TEA PLATE PINK)
#
#                            consequents  antecedent support
# 369         (REGENCY TEA PLATE GREEN )            0.011127  \
# 370         (REGENCY TEA PLATE ROSES )            0.011536
# 382      (RED RETROSPOT CHARLOTTE BAG)            0.011167
# 405  (GREEN REGENCY TEACUP AND SAUCER)            0.013785
# 124         (REGENCY TEA PLATE GREEN )            0.012845
#
#      consequent support   support  confidence       lift  leverage
# 369            0.015790  0.010554    0.948529  60.071891  0.010378  \
# 370            0.018694  0.010554    0.914894  48.939802  0.010338
# 382            0.042952  0.010104    0.904762  21.064580  0.009624
# 405            0.043238  0.012395    0.899110  20.794359  0.011799
# 124            0.015790  0.011536    0.898089  56.877430  0.011333
#
#      conviction  zhangs_metric
# 369   19.121796       0.994418
# 370   11.530342       0.990999
# 382   10.049006       0.963284
# 405    9.483198       0.965216
# 124    9.657562       0.995201

# %%
#Let's group by InvoiceNo
#https://www.skytowner.com/explore/merging_rows_within_a_group_together_in_pandas
df['InvoiceNo'] = df['InvoiceNo'].astype(str)
df['StockCode'] = df['StockCode'].astype(str)
#convert invoice number to str for further work
new_df = df.groupby('InvoiceNo', as_index=False).agg({'InvoiceNo' : 'first', 'StockCode' : ' '.join})
new_df.head()
#problem : I lost other columns
#This dataframe can be helpful to find which product goes with which product, regardless of quantity and unit price
# Out:
#   InvoiceNo                                          StockCode
# 0    536365      85123A 71053 84406B 84029G 84029E 22752 21730
# 1    536366                                        22633 22632
# 2    536367  48187 21777 21755 21754 22623 84969 22310 2274...
# 3    536368                            22914 22912 22913 22960
# 4    536369                                              21756

# %%
df.head()
# Out:
#   InvoiceNo StockCode  Quantity  UnitPrice
# 0    536365    85123A         6       2.55
# 1    536365     71053         6       3.39
# 2    536365    84406B         8       2.75
# 3    536365    84029G         6       3.39
# 4    536365    84029E         6       3.39

# %%
#remove negative data
#having negative quantities and negative prices is incoherent, so we need to remove them

# %%
#drop the StockCode or Description as they represent the same information (each product as a defined stockCode)

# %%
##################### new
# Online shopping time distribution
# Convert the transactionDate column to datetime format
df['InvoiceDate'] = pd.to_datetime(df['InvoiceDate'])

# Extract the hour information from the transactionDate column
df['hour'] = df['InvoiceDate'].dt.hour

# Count the frequency of purchases by hour
hour_counts = df['hour'].value_counts().sort_index()

# Create a bar chart of the frequency of purchases by hour
plt.bar(hour_counts.index, hour_counts.values)
plt.xlabel('Hour of Day')
plt.ylabel('Frequency')
plt.title('Online Shopping time distribution')
plt.show()

# we can see from the plot that thers is a bias between the hour of day and order volume.
# Most orders happens between 10:00 and 16:00

#no null customer df_no_null_customer
df_no_null_customer['InvoiceDate'] = pd.to_datetime(df_no_null_customer['InvoiceDate'])

# Extract the hour information from the transactionDate column
df_no_null_customer['hour'] = df_no_null_customer['InvoiceDate'].dt.hour

# Count the frequency of purchases by hour
hour_counts = df_no_null_customer['hour'].value_counts().sort_index()

# Create a bar chart of the frequency of purchases by hour
plt.bar(hour_counts.index, hour_counts.values)
plt.xlabel('Hour of Day')
plt.ylabel('Frequency')
plt.title('Online Shopping time distribution')
plt.show()
# Out:
# /var/folders/2g/lqhss3k57dd4n0cz_9xkn4rh0000gn/T/ipykernel_29744/1557706652.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_no_null_customer['InvoiceDate'] = pd.to_datetime(df_no_null_customer['InvoiceDate'])
# /var/folders/2g/lqhss3k57dd4n0cz_9xkn4rh0000gn/T/ipykernel_29744/1557706652.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_no_null_customer['hour'] = df_no_null_customer['InvoiceDate'].dt.hour

# %%
""""
# code for percentage of orders by country with a set size for the pie chart
# Orders by country and finding the top country
# Group the data by country
country_counts = df.groupby('Country').agg({'InvoiceNo': 'nunique'}).reset_index()

# Calculate the percentage of orders for each country
country_counts['pct'] = country_counts['InvoiceNo'] / country_counts['InvoiceNo'].sum()

# Sort the data by percentage
country_counts = country_counts.sort_values('pct', ascending=False)

# Create a pie chart of the percentage of orders for each country
plt.figure(figsize=(15, 8))
plt.pie(country_counts['pct'], labels=country_counts['Country'], autopct='%1.1f%%')
plt.title('Percentage of Orders by Country')
plt.show()
"""
# Orders by country and finding the top country
# Group the data by country
country_counts = df.groupby('Country').agg({'InvoiceNo': 'nunique'}).reset_index()

# Calculate the percentage of orders for each country
country_counts['pct'] = country_counts['InvoiceNo'] / country_counts['InvoiceNo'].sum()

# Sort the data by percentage
country_counts = country_counts.sort_values('pct', ascending=False)

# Create a pie chart of the percentage of orders for each country
plt.pie(country_counts['pct'], labels=country_counts['Country'], autopct='%1.1f%%')

plt.title('Percentage of Orders by Country')
plt.show()
#plot.pie(autopct="%1.1f%%",figsize=(15, 8))

# we can se that most transactions come from from the UK

# Quantity ratio by country 
df.groupby('Country')['Quantity'].sum().sort_values(ascending=False).head(10).plot.pie(autopct="%1.1f%%");
plt.title('Quantity ratio by countries')
#df.groupby('Country')['Quantity'].sum().sort_values(ascending=False).head(10).plot.pie(autopct="%1.1f%%",figsize=(15, 8));
# Out:
# Text(0.5, 1.0, 'Quantity ratio by countries')

# %%
# no null customer
# Orders by country and finding the top country
# Group the data by country
country_counts = df_no_null_customer.groupby('Country').agg({'InvoiceNo': 'nunique'}).reset_index()

# Calculate the percentage of orders for each country
country_counts['pct'] = country_counts['InvoiceNo'] / country_counts['InvoiceNo'].sum()

# Sort the data by percentage
country_counts = country_counts.sort_values('pct', ascending=False)

# Create a pie chart of the percentage of orders for each country
plt.pie(country_counts['pct'], labels=country_counts['Country'], autopct='%1.1f%%')
plt.title('Percentage of Orders by Country')
plt.show()
#plot.pie(autopct="%1.1f%%",figsize=(15, 8))

# we can se that most transactions come from from the UK

# Quantity ratio by country 
df.groupby('Country')['Quantity'].sum().sort_values(ascending=False).head(10).plot.pie(autopct="%1.1f%%");
plt.title('Quantity ratio by countries')
# Out:
# Text(0.5, 1.0, 'Quantity ratio by countries')

# %%
# Orders by country and finding the top countries
# Filter the data for the specified countries
specified_countries = ['United Kingdom', 'France', 'Germany']
filtered_df = df[df['Country'].isin(specified_countries)]

# Group the data by country
country_counts = filtered_df['Country'].value_counts()

# Calculate the percentage of orders for each country
country_pct = country_counts / country_counts.sum()

# Get the countries other than the specified countries
other_countries = df[~df['Country'].isin(specified_countries)]['Country']

# Count the orders for each other country
other_country_counts = other_countries.value_counts()

# Calculate the percentage for "Other Country" (sum of percentages of all other countries)
other_country_pct = other_country_counts.sum() / country_counts.sum()

# Create a new DataFrame with the specified countries and the "Other Country" slice
top_countries = pd.concat([country_pct, pd.Series({'Other Country': other_country_pct})])

# Create a pie chart of the percentage of orders for each country
plt.pie(top_countries, labels=top_countries.index, autopct='%1.1f%%')

plt.title('Percentage of Orders by Country')
plt.show()

# %%
# Convert the data types of the columns
df['InvoiceNo'] = df['InvoiceNo'].astype(str)
df['StockCode'] = df['StockCode'].astype(str)
df['Description'] = df['Description'].astype(str)
df['Quantity'] = pd.to_numeric(df['Quantity'], errors='coerce')
df['InvoiceDate'] = pd.to_datetime(df['InvoiceDate'])
df['UnitPrice'] = pd.to_numeric(df['UnitPrice'], errors='coerce')
df['CustomerID'] = df['CustomerID'].astype(str)
df['Country'] = df['Country'].astype(str)

# Calculate the total revenue for each product
df['Revenue'] = df['Quantity'] * df['UnitPrice']

# Calculate the top 10 best-selling products by revenue
top_products = df.groupby(['Description'])['Revenue'].sum().reset_index().sort_values(by='Revenue', ascending=False)[:10]

# Calculate the mean revenue across all products
mean_revenue = df['Revenue'].mean()

# Create a new column to indicate whether the revenue is above or below the mean
top_products['Above_Mean'] = top_products['Revenue'] > mean_revenue

# Set the color for the bars based on whether the revenue is above or below the mean
colors = top_products['Above_Mean'].map({True: 'blue', False: 'red'})

# Create the diverging bar chart
plt.barh(top_products['Description'], top_products['Revenue'], color=colors)
plt.axvline(x=mean_revenue, color='black', linestyle='--')
plt.xlabel('Revenue')
plt.title('Top 10 Best-Selling Products by Revenue')
plt.show()

# %%
# Convert the data types of the columns
df_no_null_customer['InvoiceNo'] = df_no_null_customer['InvoiceNo'].astype(str)
df_no_null_customer['StockCode'] = df_no_null_customer['StockCode'].astype(str)
df_no_null_customer['Description'] = df_no_null_customer['Description'].astype(str)
df_no_null_customer['Quantity'] = pd.to_numeric(df_no_null_customer['Quantity'], errors='coerce')
df_no_null_customer['InvoiceDate'] = pd.to_datetime(df_no_null_customer['InvoiceDate'])
df_no_null_customer['UnitPrice'] = pd.to_numeric(df_no_null_customer['UnitPrice'], errors='coerce')
df_no_null_customer['CustomerID'] = df_no_null_customer['CustomerID'].astype(str)
df_no_null_customer['Country'] = df_no_null_customer['Country'].astype(str)

# Calculate the total revenue for each product
df_no_null_customer['Revenue'] = df_no_null_customer['Quantity'] * df_no_null_customer['UnitPrice']

# Calculate the top 10 best-selling products by revenue
top_products = df_no_null_customer.groupby(['Description'])['Revenue'].sum().reset_index().sort_values(by='Revenue', ascending=False)[:10]

# Calculate the mean revenue across all products
mean_revenue = df_no_null_customer['Revenue'].mean()

# Create a new column to indicate whether the revenue is above or below the mean
top_products['Above_Mean'] = top_products['Revenue'] > mean_revenue

# Set the color for the bars based on whether the revenue is above or below the mean
colors = top_products['Above_Mean'].map({True: 'blue', False: 'red'})

# Create the diverging bar chart
plt.barh(top_products['Description'], top_products['Revenue'], color=colors)
plt.axvline(x=mean_revenue, color='black', linestyle='--')
plt.xlabel('Revenue')
plt.title('Top 10 Best-Selling Products by Revenue')
plt.show()
# Out:
# /var/folders/2g/lqhss3k57dd4n0cz_9xkn4rh0000gn/T/ipykernel_29744/3164966532.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_no_null_customer['InvoiceNo'] = df_no_null_customer['InvoiceNo'].astype(str)
# /var/folders/2g/lqhss3k57dd4n0cz_9xkn4rh0000gn/T/ipykernel_29744/3164966532.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_no_null_customer['StockCode'] = df_no_null_customer['StockCode'].astype(str)
# /var/folders/2g/lqhss3k57dd4n0cz_9xkn4rh0000gn/T/ipykernel_29744/3164966532.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_no_null_customer['Description'] = df_no_null_customer['Description'].astype(str)
# /var/folders/2g/lqhss3k57dd4n0cz_9xkn4rh0000gn/T/ipykernel_29744/3164966532.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_no_null_customer['Quantity'] = pd.to_numeric(df_no_null_customer['Quantity'], errors='coerce')
# /var/folders/2g/lqhss3k57dd4n0cz_9xkn4rh0000gn/T/ipykernel_29744/3164966532.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_no_null_customer['InvoiceDate'] = pd.to_datetime(df_no_null_customer['InvoiceDate'])
# /var/folders/2g/lqhss3k57dd4n0cz_9xkn4rh0000gn/T/ipykernel_29744/3164966532.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_no_null_customer['UnitPrice'] = pd.to_numeric(df_no_null_customer['UnitPrice'], errors='coerce')
# /var/folders/2g/lqhss3k57dd4n0cz_9xkn4rh0000gn/T/ipykernel_29744/3164966532.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_no_null_customer['CustomerID'] = df_no_null_customer['CustomerID'].astype(str)
# /var/folders/2g/lqhss3k57dd4n0cz_9xkn4rh0000gn/T/ipykernel_29744/3164966532.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_no_null_customer['Country'] = df_no_null_customer['Country'].astype(str)
# /var/folders/2g/lqhss3k57dd4n0cz_9xkn4rh0000gn/T/ipykernel_29744/3164966532.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_no_null_customer['Revenue'] = df_no_null_customer['Quantity'] * df_no_null_customer['UnitPrice']

# %%
import seaborn as sns


# Convert the 'InvoiceDate' column to datetime type
df['InvoiceDate'] = pd.to_datetime(df['InvoiceDate'])

# Group the data by month and calculate the total sales
sales_by_month = df.groupby(df['InvoiceDate'].dt.month)['Quantity'].sum()

# Create the bar plot
plt.figure(figsize=(10, 5))
sns.barplot(x=sales_by_month.index, y=sales_by_month.values)
plt.title("Month-wise Sales")
plt.xlabel("Month")
plt.ylabel("Sales")

# Show the plot
plt.show()


# no null customer

# Convert the 'InvoiceDate' column to datetime type
df_no_null_customer['InvoiceDate'] = pd.to_datetime(df_no_null_customer['InvoiceDate'])

# Group the data by month and calculate the total sales
sales_by_month = df_no_null_customer.groupby(df_no_null_customer['InvoiceDate'].dt.month)['Quantity'].sum()

# Create the bar plot
plt.figure(figsize=(10, 5))
sns.barplot(x=sales_by_month.index, y=sales_by_month.values)
plt.title("Month-wise Sales")
plt.xlabel("Month")
plt.ylabel("Sales")

# Show the plot
plt.show()
# Out:
# /var/folders/2g/lqhss3k57dd4n0cz_9xkn4rh0000gn/T/ipykernel_29744/2960585891.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_no_null_customer['InvoiceDate'] = pd.to_datetime(df_no_null_customer['InvoiceDate'])

# %%
# Convert the 'InvoiceDate' column to datetime type
df['InvoiceDate'] = pd.to_datetime(df['InvoiceDate'])

# Group the data by year and calculate the total sales
sales_by_year = df.groupby(df['InvoiceDate'].dt.year)['Quantity'].sum()

# Create the bar plot
plt.figure(figsize=(10, 5))
sns.barplot(x=sales_by_year.index, y=sales_by_year.values)
plt.title("Year-wise Sales")
plt.xlabel("Year")
plt.ylabel("Sales")

# Show the plot
plt.show()



# no null customer
df_no_null_customer['InvoiceDate'] = pd.to_datetime(df['InvoiceDate'])

# Group the data by year and calculate the total sales
sales_by_year = df_no_null_customer.groupby(df_no_null_customer['InvoiceDate'].dt.year)['Quantity'].sum()

# Create the bar plot
plt.figure(figsize=(10, 5))
sns.barplot(x=sales_by_year.index, y=sales_by_year.values)
plt.title("Year-wise Sales")
plt.xlabel("Year")
plt.ylabel("Sales")

# Show the plot
plt.show()
# Out:
# /var/folders/2g/lqhss3k57dd4n0cz_9xkn4rh0000gn/T/ipykernel_29744/3300021716.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_no_null_customer['InvoiceDate'] = pd.to_datetime(df['InvoiceDate'])

# %%
# installing apyori for Assciciation Discovery 
# !pip install apyori
# Out:
# Collecting apyori
#   Downloading apyori-1.1.2.tar.gz (8.6 kB)
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: apyori
#   Building wheel for apyori (setup.py) ... done
#   Created wheel for apyori: filename=apyori-1.1.2-py3-none-any.whl size=5956 sha256=61d7097a7b7f2142b2bf395f421d7284ff74e4c271d566ae16d9c2d227b66f4b
#   Stored in directory: /Users/amani/Library/Caches/pip/wheels/77/3d/a6/d317a6fb32be58a602b1e8c6b5d6f31f79322da554cad2a5ea
# Successfully built apyori
# Installing collected packages: apyori
# Successfully installed apyori-1.1.2
#
# [notice] A new release of pip is available: 23.1 -> 23.1.2
# [notice] To update, run: pip install --upgrade pip

# %%
#Assciciation Discovery based on customerID

cust_level = df[["CustomerID", "Description"]].sort_values(by = "CustomerID", ascending = False) ## Selecting only required variables for modelling
cust_level['Description'] = cust_level['Description'].str.strip() # Removing white spaces if any
cust_level
# Out:
#        CustomerID                          Description
# 75041         nan    BEADED PEARL HEART WHITE ON STICK
# 171866        nan             RED RETROSPOT OVEN GLOVE
# 171864        nan   SET/20 RED RETROSPOT PAPER NAPKINS
# 171863        nan        36 PENCILS TUBE RED RETROSPOT
# 171862        nan               STRAWBERRY BATH SPONGE
# ...           ...                                  ...
# 14945     12347.0    RED DRAWER KNOB ACRYLIC EDWARDIAN
# 14944     12347.0  GREEN DRAWER KNOB ACRYLIC EDWARDIAN
# 14943     12347.0   PINK DRAWER KNOB ACRYLIC EDWARDIAN
# 535010    12347.0               WOODLAND CHARLOTTE BAG
# 61619     12346.0       MEDIUM CERAMIC TOP STORAGE JAR
#
# [531283 rows x 2 columns]

# %%
# create transaction list
transactions = [a[1]['Description'].tolist() for a in list(cust_level.groupby(['CustomerID']))] ## Combing all the items in list format for each cutomer

# train model
from apyori import apriori ## Importing apriori package
rules = apriori(transactions = transactions, min_support = 0.002, min_confidence = 0.05, min_lift = 3, min_length = 2, max_length = 2)
results = list(rules)

# %%
## Creating user-defined function for arranging the results obtained from model into readable format

def inspect(results):
    lhs         = [tuple(result[2][0][0])[0] for result in results]
    rhs         = [tuple(result[2][0][1])[0] for result in results]
    supports    = [result[1] for result in results]
    confidences = [result[2][0][2] for result in results]
    lifts       = [result[2][0][3] for result in results]
    return list(zip(lhs, rhs, supports, confidences, lifts))
resultsinDataFrame = pd.DataFrame(inspect(results), columns = ['Left Hand Side', 'Right Hand Side', 'Support', 'Confidence', 'Lift'])

resultsinDataFrame.nlargest(n=50, columns="Lift") ## Showing best possible scenarios
# Out:
#                             Left Hand Side                    Right Hand Side
# 291117            GREEN ENAMEL FLOWER RING          PURPLE ENAMEL FLOWER RING  \
# 397659          NUMBER TILE VINTAGE FONT 4         NUMBER TILE VINTAGE FONT 6
# 397614        NUMBER TILE COTTAGE GARDEN 0       NUMBER TILE COTTAGE GARDEN 8
# 204589                 DOLLY GIRL WALL ART                  SPACEBOY WALL ART
# 397609        NUMBER TILE COTTAGE GARDEN 0       NUMBER TILE COTTAGE GARDEN 3
# 397612        NUMBER TILE COTTAGE GARDEN 0       NUMBER TILE COTTAGE GARDEN 6
# 397638        NUMBER TILE COTTAGE GARDEN 3       NUMBER TILE COTTAGE GARDEN 6
# 397640        NUMBER TILE COTTAGE GARDEN 3       NUMBER TILE COTTAGE GARDEN 9
# 397650        NUMBER TILE COTTAGE GARDEN 6       NUMBER TILE COTTAGE GARDEN 9
# 291118            GREEN ENAMEL FLOWER RING             RED ENAMEL FLOWER RING
# 397639        NUMBER TILE COTTAGE GARDEN 3       NUMBER TILE COTTAGE GARDEN 8
# 397649        NUMBER TILE COTTAGE GARDEN 6       NUMBER TILE COTTAGE GARDEN 8
# 98741    BLUE/YELLOW FLOWER DESIGN BIG MUG  YELLOW/PINK FLOWER DESIGN BIG MUG
# 397610        NUMBER TILE COTTAGE GARDEN 0       NUMBER TILE COTTAGE GARDEN 4
# 353639  LARGE  TALL CAMPHOR WOOD TOADSTOOL  LARGE CAMPHOR WOOD FIELD MUSHROOM
# 442264           PURPLE ENAMEL FLOWER RING             RED ENAMEL FLOWER RING
# 397611        NUMBER TILE COTTAGE GARDEN 0       NUMBER TILE COTTAGE GARDEN 5
# 397615        NUMBER TILE COTTAGE GARDEN 0       NUMBER TILE COTTAGE GARDEN 9
# 397637        NUMBER TILE COTTAGE GARDEN 3       NUMBER TILE COTTAGE GARDEN 5
# 350576     KITCHEN FLOWER POTS WALL PLAQUE   SMALL KITCHEN FLOWER POTS PLAQUE
# 434647    PINK/GREEN FLOWER DESIGN BIG MUG  YELLOW/PINK FLOWER DESIGN BIG MUG
# 397608        NUMBER TILE COTTAGE GARDEN 0       NUMBER TILE COTTAGE GARDEN 2
# 397613        NUMBER TILE COTTAGE GARDEN 0       NUMBER TILE COTTAGE GARDEN 7
# 397631        NUMBER TILE COTTAGE GARDEN 2       NUMBER TILE COTTAGE GARDEN 6
# 397644        NUMBER TILE COTTAGE GARDEN 4       NUMBER TILE COTTAGE GARDEN 8
# 397636        NUMBER TILE COTTAGE GARDEN 3       NUMBER TILE COTTAGE GARDEN 4
# 49883    ANT COPPER LIME BOUDICCA BRACELET  ANT COPPER TURQ BOUDICCA BRACELET
# 397642        NUMBER TILE COTTAGE GARDEN 4       NUMBER TILE COTTAGE GARDEN 6
# 397656          NUMBER TILE VINTAGE FONT 3         NUMBER TILE VINTAGE FONT 6
# 397655        NUMBER TILE COTTAGE GARDEN 8       NUMBER TILE COTTAGE GARDEN 9
# 397647        NUMBER TILE COTTAGE GARDEN 5       NUMBER TILE COTTAGE GARDEN 8
# 98740    BLUE/YELLOW FLOWER DESIGN BIG MUG   PINK/GREEN FLOWER DESIGN BIG MUG
# 397629        NUMBER TILE COTTAGE GARDEN 2       NUMBER TILE COTTAGE GARDEN 4
# 397633        NUMBER TILE COTTAGE GARDEN 2       NUMBER TILE COTTAGE GARDEN 8
# 397641        NUMBER TILE COTTAGE GARDEN 4       NUMBER TILE COTTAGE GARDEN 5
# 397648        NUMBER TILE COTTAGE GARDEN 6       NUMBER TILE COTTAGE GARDEN 7
# 397628        NUMBER TILE COTTAGE GARDEN 2       NUMBER TILE COTTAGE GARDEN 3
# 128801          CAST IRON HOOK GARDEN FORK       CAST IRON HOOK GARDEN TROWEL
# 397634        NUMBER TILE COTTAGE GARDEN 2       NUMBER TILE COTTAGE GARDEN 9
# 397646        NUMBER TILE COTTAGE GARDEN 5       NUMBER TILE COTTAGE GARDEN 7
# 397651        NUMBER TILE COTTAGE GARDEN 7       NUMBER TILE COTTAGE GARDEN 8
# 397645        NUMBER TILE COTTAGE GARDEN 4       NUMBER TILE COTTAGE GARDEN 9
# 397607        NUMBER TILE COTTAGE GARDEN 0       NUMBER TILE COTTAGE GARDEN 1
# 397617        NUMBER TILE COTTAGE GARDEN 1       NUMBER TILE COTTAGE GARDEN 3
# 397620        NUMBER TILE COTTAGE GARDEN 1       NUMBER TILE COTTAGE GARDEN 6
# 397643        NUMBER TILE COTTAGE GARDEN 4       NUMBER TILE COTTAGE GARDEN 7
# 397630        NUMBER TILE COTTAGE GARDEN 2       NUMBER TILE COTTAGE GARDEN 5
# 397652        NUMBER TILE COTTAGE GARDEN 7       NUMBER TILE COTTAGE GARDEN 9
# 468173           ROSE DU SUD COSMETICS BAG                ROSE DU SUD WASHBAG
# 397632        NUMBER TILE COTTAGE GARDEN 2       NUMBER TILE COTTAGE GARDEN 7
#
#          Support  Confidence        Lift
# 291117  0.002304    1.000000  361.666667
# 397659  0.002074    0.900000  355.090909
# 397614  0.002304    0.909091  328.787879
# 204589  0.002074    0.900000  325.500000
# 397609  0.002074    0.818182  322.809917
# 397612  0.002074    0.818182  322.809917
# 397638  0.002074    0.818182  322.809917
# 397640  0.002304    0.909091  303.496503
# 397650  0.002304    0.909091  303.496503
# 291118  0.002074    0.900000  300.461538
# 397639  0.002074    0.818182  295.909091
# 397649  0.002074    0.818182  295.909091
# 98741   0.002535    0.916667  284.166667
# 397610  0.002304    0.909091  281.818182
# 353639  0.002074    0.642857  279.000000
# 442264  0.002304    0.833333  278.205128
# 397611  0.002074    0.818182  273.146853
# 397615  0.002074    0.818182  273.146853
# 397637  0.002074    0.818182  273.146853
# 350576  0.002074    0.750000  271.250000
# 434647  0.003226    0.875000  271.250000
# 397608  0.002304    0.909091  263.030303
# 397613  0.002304    0.909091  263.030303
# 397631  0.002304    0.666667  263.030303
# 397644  0.002304    0.714286  258.333333
# 397636  0.002074    0.818182  253.636364
# 49883   0.002074    0.642857  253.636364
# 397642  0.002074    0.642857  253.636364
# 397656  0.002074    0.642857  253.636364
# 397655  0.002074    0.750000  250.384615
# 397647  0.002074    0.692308  250.384615
# 98740   0.002535    0.916667  248.645833
# 397629  0.002765    0.800000  248.000000
# 397633  0.002304    0.666667  241.111111
# 397641  0.002304    0.714286  238.461538
# 397648  0.002074    0.818182  236.727273
# 397628  0.002074    0.600000  236.727273
# 128801  0.002074    0.692308  231.124260
# 397634  0.002304    0.666667  222.564103
# 397646  0.002304    0.769231  222.564103
# 397651  0.002074    0.600000  217.000000
# 397645  0.002074    0.642857  214.615385
# 397607  0.002304    0.909091  207.655502
# 397617  0.002304    0.526316  207.655502
# 397620  0.002304    0.526316  207.655502
# 397643  0.002304    0.714286  206.666667
# 397630  0.002074    0.600000  200.307692
# 397652  0.002074    0.600000  200.307692
# 468173  0.002304    0.588235  196.380090
# 397632  0.002304    0.666667  192.888889

# %%
# Association discovery (some results as Eliott)

import pandas as pd
from mlxtend.frequent_patterns import apriori, association_rules

# Load the data and sort by 'InvoiceDate'
df_no_null_customer['InvoiceDate'] = pd.to_datetime(df['InvoiceDate'])
df_no_null_customer = df_no_null_customer.sort_values(by='InvoiceDate')
df_no_null_customer = df_no_null_customer.set_index('InvoiceDate')

# Print dataset shape and information
#print('Dataset Shape:', df.shape)
#print(df.info())
#print(df.head())

# Add 'selled' column
df_no_null_customer['selled'] = 1

# Pivot the table
pivot = df_no_null_customer.pivot_table(values='selled', index='InvoiceNo', columns='Description').fillna(0)

# Print pivot table shape and information
#print('Pivot Table Shape:', pivot.shape)
#print(pivot.info())
#print(pivot.head())

# Keep the first 4104 columns
pivot = pivot.iloc[:, :4104]
#print(pivot.shape)

# Generate frequent items using Apriori algorithm
freq_items = apriori(pivot, min_support=0.02, use_colnames=True).sort_values(by='support', ascending=False)
#print(freq_items)

# Generate association rules
rules = association_rules(freq_items, metric='lift', min_threshold=1).sort_values(by='lift', ascending=False)


# Sort the rules based on the metric you are interested in (e.g., lift)
sorted_rules = rules.sort_values(by='confidence', ascending=False)

# Show the top 10 rules with the highest lift
top_rules = sorted_rules.head(10)

#top_rules.head()
# Out:
# /var/folders/2g/lqhss3k57dd4n0cz_9xkn4rh0000gn/T/ipykernel_29744/2541273356.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_no_null_customer['InvoiceDate'] = pd.to_datetime(df['InvoiceDate'])
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/mlxtend/frequent_patterns/fpcommon.py:110: DeprecationWarning: DataFrames with non-bool types result in worse computationalperformance and their support might be discontinued in the future.Please use a DataFrame with bool type
#   warnings.warn(

# %%
# Out:
#                                           antecedents
# 39                   (PINK REGENCY TEACUP AND SAUCER)  \
# 38  (ROSES REGENCY TEACUP AND SAUCER , GREEN REGEN...
# 37  (ROSES REGENCY TEACUP AND SAUCER , PINK REGENC...
# 40                  (GREEN REGENCY TEACUP AND SAUCER)
# 13                  (GREEN REGENCY TEACUP AND SAUCER)
#
#                                           consequents  antecedent support
# 39  (ROSES REGENCY TEACUP AND SAUCER , GREEN REGEN...            0.038045  \
# 38                   (PINK REGENCY TEACUP AND SAUCER)            0.038144
# 37                  (GREEN REGENCY TEACUP AND SAUCER)            0.029751
# 40  (ROSES REGENCY TEACUP AND SAUCER , PINK REGENC...            0.050412
# 13                   (PINK REGENCY TEACUP AND SAUCER)            0.050412
#
#     consequent support   support  confidence       lift  leverage  conviction
# 39            0.038144  0.026920    0.707572  18.549806  0.025468    3.289203  \
# 38            0.038045  0.026920    0.705729  18.549806  0.025468    3.268944
# 37            0.050412  0.026920    0.904841  17.948844  0.025420    9.979001
# 40            0.029751  0.026920    0.533990  17.948844  0.025420    2.082036
# 13            0.038045  0.031439    0.623645  16.392265  0.029521    2.555980
#
#     zhangs_metric
# 39       0.983509
# 38       0.983610
# 37       0.973241
# 40       0.994417
# 13       0.988846

# %%
# Out:
#                                            antecedents
# 369  (REGENCY TEA PLATE ROSES , REGENCY TEA PLATE P...  \
# 370  (REGENCY TEA PLATE GREEN , REGENCY TEA PLATE P...
# 382  (CHARLOTTE BAG SUKI DESIGN, STRAWBERRY CHARLOT...
# 405  (ROSES REGENCY TEACUP AND SAUCER , PINK REGENC...
# 124                           (REGENCY TEA PLATE PINK)
#
#                            consequents  antecedent support
# 369         (REGENCY TEA PLATE GREEN )            0.011127  \
# 370         (REGENCY TEA PLATE ROSES )            0.011536
# 382      (RED RETROSPOT CHARLOTTE BAG)            0.011167
# 405  (GREEN REGENCY TEACUP AND SAUCER)            0.013785
# 124         (REGENCY TEA PLATE GREEN )            0.012845
#
#      consequent support   support  confidence       lift  leverage
# 369            0.015790  0.010554    0.948529  60.071891  0.010378  \
# 370            0.018694  0.010554    0.914894  48.939802  0.010338
# 382            0.042952  0.010104    0.904762  21.064580  0.009624
# 405            0.043238  0.012395    0.899110  20.794359  0.011799
# 124            0.015790  0.011536    0.898089  56.877430  0.011333
#
#      conviction  zhangs_metric
# 369   19.121796       0.994418
# 370   11.530342       0.990999
# 382   10.049006       0.963284
# 405    9.483198       0.965216
# 124    9.657562       0.995201

# %%
import pandas as pd
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import apriori, association_rules


# Convert the data into a transaction format
transactions = df.groupby('InvoiceNo')['Description'].apply(list).tolist()

# Apply one-hot encoding to the transaction data
te = TransactionEncoder()
encoded_data = te.fit_transform(transactions)
encoded_df = pd.DataFrame(encoded_data, columns=te.columns_)

# Generate frequent itemsets using Apriori
frequent_itemsets = apriori(encoded_df, min_support=0.01, use_colnames=True)

# Generate association rules with three products
association_rules = association_rules(frequent_itemsets, metric="lift", min_threshold=1)
association_rules_three_products = association_rules[association_rules['antecedents'].apply(lambda x: len(x) == 2 and len(x.union({'Description'})) == 3)]

# Print the resulting association rules
print(association_rules_three_products)
# Out:
#                                            antecedents
# 600  (ALARM CLOCK BAKELIKE RED , ALARM CLOCK BAKELI...  \
# 601  (ALARM CLOCK BAKELIKE RED , ALARM CLOCK BAKELI...
# 602  (ALARM CLOCK BAKELIKE GREEN, ALARM CLOCK BAKEL...
# 606  (ALARM CLOCK BAKELIKE RED , ALARM CLOCK BAKELI...
# 607  (ALARM CLOCK BAKELIKE RED , ALARM CLOCK BAKELI...
# ..                                                 ...
# 925  (LUNCH BAG PINK POLKADOT, LUNCH BAG RED RETROS...
# 926  (LUNCH BAG PINK POLKADOT, LUNCH BAG  BLACK SKU...
# 927     (LUNCH BAG CARS BLUE, LUNCH BAG RED RETROSPOT)
# 928     (LUNCH BAG  BLACK SKULL., LUNCH BAG CARS BLUE)
# 929  (LUNCH BAG  BLACK SKULL., LUNCH BAG RED RETROS...
#
#                                            consequents  antecedent support
# 600                       (ALARM CLOCK BAKELIKE IVORY)            0.028593  \
# 601                       (ALARM CLOCK BAKELIKE GREEN)            0.016940
# 602                        (ALARM CLOCK BAKELIKE RED )            0.014836
# 606                        (ALARM CLOCK BAKELIKE PINK)            0.028593
# 607                       (ALARM CLOCK BAKELIKE GREEN)            0.021364
# ..                                                 ...                 ...
# 925     (LUNCH BAG  BLACK SKULL., LUNCH BAG CARS BLUE)            0.028215
# 926     (LUNCH BAG CARS BLUE, LUNCH BAG RED RETROSPOT)            0.025032
# 927  (LUNCH BAG PINK POLKADOT, LUNCH BAG  BLACK SKU...            0.024709
# 928  (LUNCH BAG PINK POLKADOT, LUNCH BAG RED RETROS...            0.022713
# 929     (LUNCH BAG PINK POLKADOT, LUNCH BAG CARS BLUE)            0.027892
#
#      consequent support   support  confidence       lift  leverage
# 600            0.025248  0.011599    0.405660  16.066925  0.010877  \
# 601            0.042566  0.011599    0.684713  16.085991  0.010878
# 602            0.047313  0.011599    0.781818  16.524267  0.010897
# 606            0.033071  0.014404    0.503774  15.233193  0.013459
# 607            0.042566  0.014404    0.674242  15.839997  0.013495
# ..                  ...       ...         ...        ...       ...
# 925            0.022713  0.010412    0.369025  16.247612  0.009771
# 926            0.024709  0.010412    0.415948  16.834099  0.009794
# 927            0.025032  0.010412    0.421397  16.834099  0.009794
# 928            0.028215  0.010412    0.458432  16.247612  0.009771
# 929            0.023036  0.010412    0.373308  16.205219  0.009770
#
#      conviction  zhangs_metric
# 600    1.640059       0.965363
# 601    3.036710       0.953995
# 602    4.366481       0.953631
# 606    1.948565       0.961856
# 607    2.939100       0.957321
# ..          ...            ...
# 925    1.548853       0.965700
# 926    1.669871       0.964747
# 927    1.685038       0.964426
# 928    1.794392       0.960263
# 929    1.558921       0.965213
#
# [165 rows x 10 columns]

# %%
association_rules_df = pd.DataFrame(association_rules_three_products)

association_rules_df.head(10)
# Out:
#                                            antecedents
# 600  (ALARM CLOCK BAKELIKE RED , ALARM CLOCK BAKELI...  \
# 601  (ALARM CLOCK BAKELIKE RED , ALARM CLOCK BAKELI...
# 602  (ALARM CLOCK BAKELIKE GREEN, ALARM CLOCK BAKEL...
# 606  (ALARM CLOCK BAKELIKE RED , ALARM CLOCK BAKELI...
# 607  (ALARM CLOCK BAKELIKE RED , ALARM CLOCK BAKELI...
# 608  (ALARM CLOCK BAKELIKE GREEN, ALARM CLOCK BAKEL...
# 612  (GREEN REGENCY TEACUP AND SAUCER, PINK REGENCY...
# 613  (GREEN REGENCY TEACUP AND SAUCER, REGENCY CAKE...
# 614  (PINK REGENCY TEACUP AND SAUCER, REGENCY CAKES...
# 618  (GREEN REGENCY TEACUP AND SAUCER, PINK REGENCY...
#
#                             consequents  antecedent support
# 600        (ALARM CLOCK BAKELIKE IVORY)            0.028593  \
# 601        (ALARM CLOCK BAKELIKE GREEN)            0.016940
# 602         (ALARM CLOCK BAKELIKE RED )            0.014836
# 606         (ALARM CLOCK BAKELIKE PINK)            0.028593
# 607        (ALARM CLOCK BAKELIKE GREEN)            0.021364
# 608         (ALARM CLOCK BAKELIKE RED )            0.018505
# 612          (REGENCY CAKESTAND 3 TIER)            0.024817
# 613    (PINK REGENCY TEACUP AND SAUCER)            0.020177
# 614   (GREEN REGENCY TEACUP AND SAUCER)            0.016670
# 618  (ROSES REGENCY TEACUP AND SAUCER )            0.024817
#
#      consequent support   support  confidence       lift  leverage
# 600            0.025248  0.011599    0.405660  16.066925  0.010877  \
# 601            0.042566  0.011599    0.684713  16.085991  0.010878
# 602            0.047313  0.011599    0.781818  16.524267  0.010897
# 606            0.033071  0.014404    0.503774  15.233193  0.013459
# 607            0.042566  0.014404    0.674242  15.839997  0.013495
# 608            0.047313  0.014404    0.778426  16.452563  0.013529
# 612            0.091929  0.014620    0.589130   6.408522  0.012339
# 613            0.029996  0.014620    0.724599  24.156773  0.014015
# 614            0.037279  0.014620    0.877023  23.526037  0.013999
# 618            0.042242  0.021040    0.847826  20.070631  0.019992
#
#      conviction  zhangs_metric
# 600    1.640059       0.965363
# 601    3.036710       0.953995
# 602    4.366481       0.953631
# 606    1.948565       0.961856
# 607    2.939100       0.957321
# 608    4.299625       0.956927
# 612    2.210119       0.865435
# 613    3.522152       0.978344
# 614    7.828443       0.973726
# 618    6.293837       0.974356
